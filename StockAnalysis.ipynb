# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()
plt.style.use('fivethirtyeight')

# %%
data = pd.read_csv("^NSEI.csv")
print(data.head())
# Out:
#          Date          Open          High           Low         Close  \
# 0  2022-09-08  17748.150391  17807.650391  17691.949219  17798.750000
# 1  2022-09-09  17923.349609  17925.949219  17786.000000  17833.349609
# 2  2022-09-12  17890.849609  17980.550781  17889.150391  17936.349609
# 3  2022-09-13  18044.449219  18088.300781  18015.449219  18070.050781
# 4  2022-09-14  17771.150391  18091.550781  17771.150391  18003.750000
#
#       Adj Close  Volume
# 0  17798.750000  279800
# 1  17833.349609  270300
# 2  17936.349609  228200
# 3  18070.050781  259900
# 4  18003.750000  365900

# %%
plt.figure(figsize=(10, 4))
plt.title("Microsoft Stock Prices")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

# %%
numeric_data = data.select_dtypes(include=['number'])
print(numeric_data.corr())
sns.heatmap(numeric_data.corr())
plt.show()
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.997135  0.995668  0.991484   0.991484 -0.052129
# High       0.997135  1.000000  0.996210  0.996140   0.996140 -0.049022
# Low        0.995668  0.996210  1.000000  0.997212   0.997212 -0.076628
# Close      0.991484  0.996140  0.997212  1.000000   1.000000 -0.067838
# Adj Close  0.991484  0.996140  0.997212  1.000000   1.000000 -0.067838
# Volume    -0.052129 -0.049022 -0.076628 -0.067838  -0.067838  1.000000

# %%
x = data[["Open", "High", "Low"]]
y = data["Close"]
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)
data = pd.DataFrame(data={"Predicted Rate": ypred})
print(data.head())
# Out:
#    Predicted Rate
# 0    17563.949219
# 1    17589.599609
# 2    17706.849609
# 3    18633.849609
# 4    18065.000000
